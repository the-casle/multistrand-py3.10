# %% [markdown]
# <h1 id="Tutorial-4---Hairpin-first-passage-time">Tutorial 4 - Hairpin first passage time<a class="anchor-link" href="#Tutorial-4---Hairpin-first-passage-time">¶</a></h1>

# %% [markdown]
# <p>Here we ask Multistrand to simulate the folding of an open strand into a hairpin, and stop when it's done.  This mode, <strong>First Passage Time Mode</strong>, requires us to specific a start state and a recognizable stop condition (i.e. entering a macrostate), and Multistrand returns the total time it took.  Running a lot of simulations and plotting histograms and completion fractions can provide insight into the process -- and its stochastic variability.</p>

# %%
import numpy as np
import matplotlib
import matplotlib.pylab as plt
# %matplotlib inline

from multistrand.objects import *
from multistrand.options import Options
from multistrand.system import SimSystem

# %% [markdown]
# <h4 id="This-is-first-passage-time">This is first passage time<a class="anchor-link" href="#This-is-first-passage-time">¶</a></h4>

# %%
# for StopCondition and Macrostate definitions:
Exact_Macrostate = 0   # match a secondary structure exactly (i.e. any system state that has a complex with this exact structure)
Bound_Macrostate = 1   # match any system state in which the given strand is bound to another strand
Dissoc_Macrostate = 2  # match any system state in which there exists a complex with exactly the given strands, in that order
Loose_Macrostate = 3   # match a secondary structure with "don't care"s, allowing a certain number of disagreements
Count_Macrostate = 4   # match a secondary structure, allowing a certain number of disagreements
# see Schaeffer's PhD thesis, chapter 7.2, for more information

# %%
def setup_options_hairpin(trials, stem_seq, hairpin_seq):

    # Define the domains
    stem = Domain(name="stem",sequence=stem_seq,length=len(stem_seq))
    hairpin = Domain(name="hairpin", sequence=hairpin_seq,length=len(hairpin_seq))
    s = stem + hairpin + stem.C
    
    # We give domain-level structures for the open and closed hairpin configurations
    start_complex = Complex(strands=[s], structure="...")
    stop_complex  = Complex(strands=[s], structure="(.)")
    full_sc       = StopCondition( "CLOSED", [(stop_complex,Exact_Macrostate,0)])
    # Note: unlike in Transition Mode, in First Passage Time Mode, no "stop:" prefix is needed in the macrostate name
    # in order for the StopCondition to trigger the end of the simulation.

    o = Options(simulation_mode="First Passage Time",parameter_type="Nupack",substrate_type="DNA", temperature=310.15,
                num_simulations = trials, simulation_time=0.1, verbosity=0,
                start_state=[start_complex], stop_conditions=[full_sc])
    o.JSKawasaki37()
    return o

# %% [markdown]
# <p>The simulation is easy. There's more fuss and bother to define how to plot the results.</p>

# %%
def plot_histograms( result_lists, colors=['b','r','c','m','g','k'], figure=1, labels=None ):
    times = []
    for n in range(len(result_lists)):
        times.append(1e6* np.array([ i.time for i in result_lists[n] ]))    # convert from seconds to microseconds units.

    min_time = np.min( [np.min(times[n]) for n in range(len(result_lists)) ] )
    max_time = np.max( [np.max(times[n]) for n in range(len(result_lists)) ] )

    plt.figure( figure )
    for n in range(len(result_lists)):
        plt.hist( times[n], 50, range=(min_time,max_time), color = colors[n], label=labels[n], rwidth=(1-n*1.0/len(result_lists)) )

    plt.title("Folding times for two hairpin sequences")
    plt.xlabel("First Passage Time (us)",fontsize='larger')
    plt.ylabel("# of Trajectories",fontsize='larger')
    plt.yticks(fontsize='larger',va='bottom')
    plt.xticks(fontsize='larger')
    plt.legend(loc=0)
    plt.show()

def plot_completion_graph( result_lists, colors=['b','r','c','m','g','k'], figure=1, labels=None ):
    times = []
    percents = []
    if labels==None:
        labels=[str(n) for n in range(1,1+len(result_lists))]
    if len(labels) < len(colors):
        colors = colors[:len(labels)]

    for rl in result_lists:
        n = len(rl)
        t = [i.time for i in rl]
        t.sort()
        times.append(np.array(t))

        p = np.array(range(1,len(t)+1))
        p = 100 * p / n  # percentage of all trials
        percents.append( p )

    plt.figure( figure )

    for t,p,c,label in zip(times,percents,colors,labels):
        plt.plot( 1e6 * t, p, color = c, linewidth=2.0, label=label )

    plt.xlabel("Simulation Time (us)",fontsize='larger')
    plt.ylabel("% of Trajectories Complete",fontsize='larger')
    plt.yticks([0,20,40,60,80,100],("0%","20%","40%","60%","80%","100%"),fontsize='larger',va='bottom')
    plt.xticks(fontsize='larger')
    plt.title( "Percentage of Total Trajectories Complete by a Given Time" )
    plt.legend(loc=0)
    plt.show()

# %%
# First Passage Time Mode doesn't store the full trajectory.  But it gives the random number seed used on a given simulation.
# So we can re-run interesting simulations to see what happened.
# Here, we also show how to run a Trajectory Mode simulation with a StopCondition (rather than time-out).
def show_interesting_trajectories( result_lists, seqs, type='fastest' ):
    mintimes = []
    maxtimes = []
    slowseeds = []
    fastseeds = []
    for n in range(len(result_lists)):
        times = 1e6* np.array([ i.time for i in result_lists[n] ])    # convert from seconds to microseconds units.
        slowseeds.append( result_lists[n][np.argmax( times )].seed )  # find the seed used for the slowest simulation
        fastseeds.append( result_lists[n][np.argmin( times )].seed )  # find the seed used for the fastest simulation
        mintimes.append( np.min( times ) )
        maxtimes.append( np.max( times ) )

    # taken from hairpin_trajectories.py
    def print_trajectory(o):
        print(o.full_trajectory[0][0][3])   # the strand sequence
        print(o.start_state[0].structure)
        for i in range(len(o.full_trajectory)):
            time = 1e6* o.full_trajectory_times[i]
            state = o.full_trajectory[i][0]
            struct = state[4]
            dG = state[5]
            print(struct + ' t=%11.9f microseconds, dG=%6.2f kcal/mol' % (time, dG))

    # take a look at the fastest folds.  to take a look at the more interesting slowest folds,
    # change "mintimes" to "maxtimes" and change "fastseeds" to "slowseeds"; do this based on 'type' argument
    seeds = fastseeds if type=='fastest' else slowseeds
    times = mintimes if type=='fastest' else maxtimes
    for (seq,seed,time) in zip(seqs,seeds,times):
        s1 = Strand(name="hairpin", sequence=seq)
        c1 = Complex( strands=[s1], structure=16*'.' )             # hard-coded length 16
        c2 = Complex( strands=[s1], structure="((((((....))))))")  # hard-coded stem length 6, loop length 4
        sc  = StopCondition( "CLOSED", [(c2,Exact_Macrostate,0)])
        # For future reference, StopConditions and Macrostates (same thing) are provided as a list of match conditions,
        # all of which must be matched.  I.e. there is an implicit AND being evaluated.  E.g. 
        # sc = StopCondition( "EXAMPLE", [(c2,Loose_Macrostate,8), (c1,Loose_Macrostate,4)]
        # would specify the intersection of those two macrostates, i.e. any 2 base pairs of the helix (and maybe more).

        o = Options(temperature=310.15, dangles='Some', start_state = [c1], 
            simulation_time = 0.1,  # 0.1 seconds  (lots more time than hairpin_trajectories, to accommodate slow folds)
            num_simulations = 1,  # don't play it again, Sam
            output_interval = 1,  # record every single step
            rate_method = 'Metropolis', # the default is 'Kawasaki' (numerically, these are 1 and 2 respectively)
            simulation_mode = 'Trajectory')  # numerically 128.  See interface/_options/constants.py for more info about all this.
        o.stop_conditions=[sc]               # don't wait for the time-out
        o.initial_seed = seed                # start with the same random seed as before...  
        o.JSMetropolis37()
            
        s = SimSystem(o)
        s.start()
        print_trajectory(o)        
        print("Original run's time: %g microseconds" % time)

# %%
def run_sims():
    print("Performing simulations...")
    # compare closing of stems based on possible kinetic traps
    o1 = setup_options_hairpin(trials=1000, stem_seq = "GCATGC", hairpin_seq="TTTT")  # 2-base misaligned GC pairing possible
    o2 = setup_options_hairpin(trials=1000, stem_seq = "GGCGGC", hairpin_seq="TTTT")  # 3-base misaligned GGC pairing possible
    o3 = setup_options_hairpin(trials=1000, stem_seq = "GCCGCG", hairpin_seq="TTTT")  # strong stem, but no significant misaligned pairing
    o4 = setup_options_hairpin(trials=1000, stem_seq = "ATTATA", hairpin_seq="TTTT")  # weak stem, no significant misaligned pairing

    s=SimSystem(o1)
    s.start()
    s=SimSystem(o2)
    s.start()
    s=SimSystem(o3)
    s.start()
    s=SimSystem(o4)
    s.start()
    # all these simulations are at the same join_concentration and temperature,
    # so there's no need to re-initialize the energy model before each one.


    all_results = [o.interface.results for o in [o1, o2, o3, o4]]
    all_seqs    = [o.start_state[0].sequence for o in [o1, o2, o3, o4]]

    print("Plotting results...")
    plot_histograms(all_results, figure=1, labels=all_seqs)
    plot_completion_graph(all_results, figure=2, labels=all_seqs)
    # conclusions: 
    #    weak stem forms slowly, but without traps.
    #    stronger stems form quickly, but if 3-base misalignment is possible, it may take a long time

    special = 'fastest'   # or 'slowest', if you wish, but these trajectories involve many many steps!
    print("Showing the %s trajectories for each hairpin sequence..." % special)
    show_interesting_trajectories(all_results, all_seqs, special)

# %% [markdown]
# <p>OK, time to actually run the simulations.</p>

# %%
run_sims()
# Out:
# Performing simulations...
# Plotting results...
# Showing the fastest trajectories for each hairpin sequence...
# GCATGCTTTTGCATGC
# ................
# ................ t=0.000000000 microseconds, dG=  0.00 kcal/mol
# .........(....). t=0.000408788 microseconds, dG=  2.75 kcal/mol
# ................ t=0.002413895 microseconds, dG=  0.00 kcal/mol
# .....(....)..... t=0.002993262 microseconds, dG=  1.15 kcal/mol
# ................ t=0.003601555 microseconds, dG=  0.00 kcal/mol
# .....(....)..... t=0.013931326 microseconds, dG=  1.15 kcal/mol
# ....((....)).... t=0.014942899 microseconds, dG= -1.57 kcal/mol
# ...(((....)))... t=0.017440153 microseconds, dG= -1.91 kcal/mol
# ..((((....)))).. t=0.017917409 microseconds, dG= -3.34 kcal/mol
# .(((((....))))). t=0.020222371 microseconds, dG= -4.87 kcal/mol
# ((((((....)))))) t=0.020497267 microseconds, dG= -6.16 kcal/mol
# Original run's time: 0.00211539 microseconds
# GGCGGCTTTTGCCGCC
# ................
# ................ t=0.000000000 microseconds, dG=  0.00 kcal/mol
# .......(.....).. t=0.000387792 microseconds, dG=  2.85 kcal/mol
# ................ t=0.002277125 microseconds, dG=  0.00 kcal/mol
# ....(......).... t=0.002826735 microseconds, dG=  2.13 kcal/mol
# ....((....)).... t=0.003203451 microseconds, dG= -1.01 kcal/mol
# ...(((....)))... t=0.007260742 microseconds, dG= -2.33 kcal/mol
# .(.(((....))).). t=0.008342825 microseconds, dG= -1.85 kcal/mol
# .(((((....))))). t=0.009250625 microseconds, dG= -7.26 kcal/mol
# ((((((....)))))) t=0.010249027 microseconds, dG= -8.23 kcal/mol
# Original run's time: 0.000570529 microseconds
# GCCGCGTTTTCGCGGC
# ................
# ................ t=0.000000000 microseconds, dG=  0.00 kcal/mol
# .........(...).. t=0.000512369 microseconds, dG=  3.30 kcal/mol
# ................ t=0.002082141 microseconds, dG=  0.00 kcal/mol
# ....(........).. t=0.002808312 microseconds, dG=  2.14 kcal/mol
# ....((......)).. t=0.003362481 microseconds, dG= -0.23 kcal/mol
# ....(((....))).. t=0.008960221 microseconds, dG= -0.62 kcal/mol
# ....((......)).. t=0.012670231 microseconds, dG= -0.23 kcal/mol
# ....(((....))).. t=0.015260302 microseconds, dG= -0.62 kcal/mol
# ....((......)).. t=0.017040626 microseconds, dG= -0.23 kcal/mol
# ....(((....))).. t=0.019530758 microseconds, dG= -0.62 kcal/mol
# ....((......)).. t=0.020050382 microseconds, dG= -0.23 kcal/mol
# ....(((....))).. t=0.020528215 microseconds, dG= -0.62 kcal/mol
# ....((......)).. t=0.023850388 microseconds, dG= -0.23 kcal/mol
# ....(((....))).. t=0.025485198 microseconds, dG= -0.62 kcal/mol
# ....((......)).. t=0.025543768 microseconds, dG= -0.23 kcal/mol
# ....(((....))).. t=0.026531839 microseconds, dG= -0.62 kcal/mol
# ....((......)).. t=0.026582518 microseconds, dG= -0.23 kcal/mol
# ....(((....))).. t=0.029482378 microseconds, dG= -0.62 kcal/mol
# ....((......)).. t=0.033623026 microseconds, dG= -0.23 kcal/mol
# ....(((....))).. t=0.034169157 microseconds, dG= -0.62 kcal/mol
# ....((......)).. t=0.034520759 microseconds, dG= -0.23 kcal/mol
# ....(((....))).. t=0.034691534 microseconds, dG= -0.62 kcal/mol
# ....((......)).. t=0.036907719 microseconds, dG= -0.23 kcal/mol
# .(..((......))). t=0.038196311 microseconds, dG=  2.88 kcal/mol
# ....((......)).. t=0.039053921 microseconds, dG= -0.23 kcal/mol
# ....(((....))).. t=0.040806136 microseconds, dG= -0.62 kcal/mol
# ....((......)).. t=0.046011065 microseconds, dG= -0.23 kcal/mol
# ....(((....))).. t=0.046807346 microseconds, dG= -0.62 kcal/mol
# ....((......)).. t=0.048182671 microseconds, dG= -0.23 kcal/mol
# ....(((....))).. t=0.051710906 microseconds, dG= -0.62 kcal/mol
# ....((......)).. t=0.056816295 microseconds, dG= -0.23 kcal/mol
# ....(((....))).. t=0.058208131 microseconds, dG= -0.62 kcal/mol
# (...(((....))).) t=0.058349813 microseconds, dG=  2.94 kcal/mol
# ((..(((....))))) t=0.059035648 microseconds, dG=  1.20 kcal/mol
# ((...((....)).)) t=0.060103652 microseconds, dG=  2.87 kcal/mol
# (((..((....))))) t=0.061568678 microseconds, dG=  1.53 kcal/mol
# ((...((....)).)) t=0.063459333 microseconds, dG=  2.87 kcal/mol
# .(...((....)).). t=0.063843660 microseconds, dG=  4.16 kcal/mol
# .((..((....)))). t=0.064232848 microseconds, dG=  2.82 kcal/mol
# ..(..((....))).. t=0.064737420 microseconds, dG=  4.65 kcal/mol
# .((..((....)))). t=0.064831888 microseconds, dG=  2.82 kcal/mol
# .((...(....).)). t=0.064916561 microseconds, dG=  3.41 kcal/mol
# .((..((....)))). t=0.064927632 microseconds, dG=  2.82 kcal/mol
# (((..((....))))) t=0.065080649 microseconds, dG=  1.53 kcal/mol
# (((...(....).))) t=0.067340937 microseconds, dG=  2.12 kcal/mol
# (((..((....))))) t=0.068075588 microseconds, dG=  1.53 kcal/mol
# (((..(......)))) t=0.068356012 microseconds, dG=  1.92 kcal/mol
# (((..........))) t=0.068398697 microseconds, dG= -0.78 kcal/mol
# ((((........)))) t=0.070655941 microseconds, dG= -2.95 kcal/mol
# (((((......))))) t=0.070733343 microseconds, dG= -5.49 kcal/mol
# ((((((....)))))) t=0.070737430 microseconds, dG= -8.56 kcal/mol
# Original run's time: 0.000921212 microseconds
# ATTATATTTTTATAAT
# ................
# ................ t=0.000000000 microseconds, dG=  0.00 kcal/mol
# ........(.....). t=0.000495236 microseconds, dG=  2.58 kcal/mol
# ........((...)). t=0.001598193 microseconds, dG=  2.63 kcal/mol
# ........(.....). t=0.001841532 microseconds, dG=  2.58 kcal/mol
# ........((...)). t=0.002487490 microseconds, dG=  2.63 kcal/mol
# ........(.....). t=0.006826086 microseconds, dG=  2.58 kcal/mol
# ................ t=0.007900294 microseconds, dG=  0.00 kcal/mol
# .....(....)..... t=0.013690627 microseconds, dG=  1.46 kcal/mol
# ................ t=0.014238920 microseconds, dG=  0.00 kcal/mol
# ...(.....)...... t=0.019805830 microseconds, dG=  1.95 kcal/mol
# ................ t=0.020089718 microseconds, dG=  0.00 kcal/mol
# .....(.........) t=0.021157957 microseconds, dG=  2.86 kcal/mol
# .....((.......)) t=0.021904492 microseconds, dG=  1.96 kcal/mol
# .....(((.....))) t=0.023157468 microseconds, dG=  0.46 kcal/mol
# .....((.......)) t=0.023301716 microseconds, dG=  1.96 kcal/mol
# .....(((.....))) t=0.024059008 microseconds, dG=  0.46 kcal/mol
# ......((.....)). t=0.024183821 microseconds, dG=  1.68 kcal/mol
# .....(((.....))) t=0.026642205 microseconds, dG=  0.46 kcal/mol
# ......((.....)). t=0.036839916 microseconds, dG=  1.68 kcal/mol
# .....(((.....))) t=0.037302903 microseconds, dG=  0.46 kcal/mol
# ......((.....)). t=0.038168838 microseconds, dG=  1.68 kcal/mol
# .....(((.....))) t=0.038313615 microseconds, dG=  0.46 kcal/mol
# ......((.....)). t=0.043771702 microseconds, dG=  1.68 kcal/mol
# ...(..((.....))) t=0.044864118 microseconds, dG=  4.34 kcal/mol
# ......((.....)). t=0.046926119 microseconds, dG=  1.68 kcal/mol
# ......(.......). t=0.048411576 microseconds, dG=  3.18 kcal/mol
# ......((.....)). t=0.049404536 microseconds, dG=  1.68 kcal/mol
# .....(((.....))) t=0.050079592 microseconds, dG=  0.46 kcal/mol
# ......((.....)). t=0.053466782 microseconds, dG=  1.68 kcal/mol
# .....(((.....))) t=0.056457876 microseconds, dG=  0.46 kcal/mol
# ......((.....)). t=0.069031581 microseconds, dG=  1.68 kcal/mol
# .....(((.....))) t=0.070211523 microseconds, dG=  0.46 kcal/mol
# (...)(((.....))) t=0.070560460 microseconds, dG=  4.77 kcal/mol
# .....(((.....))) t=0.071731101 microseconds, dG=  0.46 kcal/mol
# ......((.....)). t=0.075271277 microseconds, dG=  1.68 kcal/mol
# .....(((.....))) t=0.078376936 microseconds, dG=  0.46 kcal/mol
# ......((.....)). t=0.087604232 microseconds, dG=  1.68 kcal/mol
# .....(((.....))) t=0.088418954 microseconds, dG=  0.46 kcal/mol
# ......((.....)). t=0.095927960 microseconds, dG=  1.68 kcal/mol
# .....(((.....))) t=0.096758414 microseconds, dG=  0.46 kcal/mol
# ......((.....)). t=0.097941382 microseconds, dG=  1.68 kcal/mol
# .....(((.....))) t=0.098080742 microseconds, dG=  0.46 kcal/mol
# .....((.......)) t=0.098271040 microseconds, dG=  1.96 kcal/mol
# .....(((.....))) t=0.098498726 microseconds, dG=  0.46 kcal/mol
# ......((.....)). t=0.109530008 microseconds, dG=  1.68 kcal/mol
# .....(((.....))) t=0.111349899 microseconds, dG=  0.46 kcal/mol
# ......((.....)). t=0.112718501 microseconds, dG=  1.68 kcal/mol
# .....(((.....))) t=0.112794129 microseconds, dG=  0.46 kcal/mol
# ......((.....)). t=0.136988849 microseconds, dG=  1.68 kcal/mol
# .....(((.....))) t=0.137124534 microseconds, dG=  0.46 kcal/mol
# .....((.......)) t=0.137144295 microseconds, dG=  1.96 kcal/mol
# .....(((.....))) t=0.140509723 microseconds, dG=  0.46 kcal/mol
# .....(.(.....).) t=0.141997833 microseconds, dG=  3.34 kcal/mol
# .....(((.....))) t=0.142411643 microseconds, dG=  0.46 kcal/mol
# .....((.......)) t=0.151811845 microseconds, dG=  1.96 kcal/mol
# .....(.........) t=0.152431088 microseconds, dG=  2.86 kcal/mol
# .....((.......)) t=0.152926371 microseconds, dG=  1.96 kcal/mol
# ......(.......). t=0.155087200 microseconds, dG=  3.18 kcal/mol
# ......((.....)). t=0.155777751 microseconds, dG=  1.68 kcal/mol
# ......(.......). t=0.156103592 microseconds, dG=  3.18 kcal/mol
# ......((.....)). t=0.156214692 microseconds, dG=  1.68 kcal/mol
# .....(((.....))) t=0.157346798 microseconds, dG=  0.46 kcal/mol
# ......((.....)). t=0.180454301 microseconds, dG=  1.68 kcal/mol
# .....(((.....))) t=0.181632782 microseconds, dG=  0.46 kcal/mol
# .....((.......)) t=0.184056143 microseconds, dG=  1.96 kcal/mol
# .....((..(...))) t=0.184129485 microseconds, dG=  5.01 kcal/mol
# .....((.......)) t=0.185439356 microseconds, dG=  1.96 kcal/mol
# .....(((.....))) t=0.185833205 microseconds, dG=  0.46 kcal/mol
# ......((.....)). t=0.198636439 microseconds, dG=  1.68 kcal/mol
# .....(((.....))) t=0.198688755 microseconds, dG=  0.46 kcal/mol
# .....((.......)) t=0.202908591 microseconds, dG=  1.96 kcal/mol
# .....(((.....))) t=0.203690862 microseconds, dG=  0.46 kcal/mol
# ......((.....)). t=0.204602003 microseconds, dG=  1.68 kcal/mol
# .....(((.....))) t=0.205137238 microseconds, dG=  0.46 kcal/mol
# ......((.....)). t=0.206001914 microseconds, dG=  1.68 kcal/mol
# .....(((.....))) t=0.207017349 microseconds, dG=  0.46 kcal/mol
# .....((.......)) t=0.221494360 microseconds, dG=  1.96 kcal/mol
# .....(((.....))) t=0.222302010 microseconds, dG=  0.46 kcal/mol
# .....((.......)) t=0.232431876 microseconds, dG=  1.96 kcal/mol
# .....(((.....))) t=0.233202507 microseconds, dG=  0.46 kcal/mol
# ......((.....)). t=0.236997329 microseconds, dG=  1.68 kcal/mol
# .....(((.....))) t=0.237404985 microseconds, dG=  0.46 kcal/mol
# ......((.....)). t=0.249523386 microseconds, dG=  1.68 kcal/mol
# ......(.......). t=0.249781156 microseconds, dG=  3.18 kcal/mol
# ................ t=0.250612411 microseconds, dG=  0.00 kcal/mol
# .....(....)..... t=0.250969354 microseconds, dG=  1.46 kcal/mol
# ................ t=0.251051631 microseconds, dG=  0.00 kcal/mol
# ...(......)..... t=0.269410253 microseconds, dG=  2.46 kcal/mol
# ................ t=0.269616758 microseconds, dG=  0.00 kcal/mol
# ...(.....)...... t=0.276495916 microseconds, dG=  1.95 kcal/mol
# ................ t=0.277413206 microseconds, dG=  0.00 kcal/mol
# .....(....)..... t=0.281311343 microseconds, dG=  1.46 kcal/mol
# ....((....)).... t=0.281948917 microseconds, dG=  1.70 kcal/mol
# ...(((....)))... t=0.282542463 microseconds, dG=  0.00 kcal/mol
# ..((((....)))).. t=0.282928096 microseconds, dG=  0.39 kcal/mol
# ...(((....)))... t=0.283185222 microseconds, dG=  0.00 kcal/mol
# ...((......))... t=0.284163066 microseconds, dG=  1.38 kcal/mol
# ...(........)... t=0.284420964 microseconds, dG=  2.38 kcal/mol
# ................ t=0.285490506 microseconds, dG=  0.00 kcal/mol
# .(............). t=0.286612002 microseconds, dG=  3.38 kcal/mol
# ................ t=0.286792543 microseconds, dG=  0.00 kcal/mol
# ...(......)..... t=0.290865028 microseconds, dG=  2.46 kcal/mol
# ................ t=0.291249819 microseconds, dG=  0.00 kcal/mol
# ......(....).... t=0.291520921 microseconds, dG=  2.38 kcal/mol
# ................ t=0.292889166 microseconds, dG=  0.00 kcal/mol
# .....(.........) t=0.294106901 microseconds, dG=  2.86 kcal/mol
# .....((.......)) t=0.295200803 microseconds, dG=  1.96 kcal/mol
# .....(((.....))) t=0.295290668 microseconds, dG=  0.46 kcal/mol
# ......((.....)). t=0.297894088 microseconds, dG=  1.68 kcal/mol
# .....(((.....))) t=0.298274341 microseconds, dG=  0.46 kcal/mol
# .....((.......)) t=0.299692360 microseconds, dG=  1.96 kcal/mol
# .....(((.....))) t=0.302251359 microseconds, dG=  0.46 kcal/mol
# ......((.....)). t=0.320875574 microseconds, dG=  1.68 kcal/mol
# .....(((.....))) t=0.321883145 microseconds, dG=  0.46 kcal/mol
# ......((.....)). t=0.330372095 microseconds, dG=  1.68 kcal/mol
# .....(((.....))) t=0.331442128 microseconds, dG=  0.46 kcal/mol
# .....((.......)) t=0.344365754 microseconds, dG=  1.96 kcal/mol
# .....(((.....))) t=0.344782450 microseconds, dG=  0.46 kcal/mol
# ......((.....)). t=0.346662579 microseconds, dG=  1.68 kcal/mol
# .....(((.....))) t=0.347902909 microseconds, dG=  0.46 kcal/mol
# ......((.....)). t=0.348796736 microseconds, dG=  1.68 kcal/mol
# ......(.......). t=0.349521192 microseconds, dG=  3.18 kcal/mol
# ......((.....)). t=0.350712700 microseconds, dG=  1.68 kcal/mol
# .....(((.....))) t=0.350828108 microseconds, dG=  0.46 kcal/mol
# .....((.......)) t=0.358275597 microseconds, dG=  1.96 kcal/mol
# .....(((.....))) t=0.358897673 microseconds, dG=  0.46 kcal/mol
# ......((.....)). t=0.365638059 microseconds, dG=  1.68 kcal/mol
# .....(((.....))) t=0.367618093 microseconds, dG=  0.46 kcal/mol
# ......((.....)). t=0.370955992 microseconds, dG=  1.68 kcal/mol
# .....(((.....))) t=0.371285042 microseconds, dG=  0.46 kcal/mol
# ......((.....)). t=0.389930281 microseconds, dG=  1.68 kcal/mol
# .....(((.....))) t=0.393719613 microseconds, dG=  0.46 kcal/mol
# ......((.....)). t=0.407905068 microseconds, dG=  1.68 kcal/mol
# .....(((.....))) t=0.408422746 microseconds, dG=  0.46 kcal/mol
# ......((.....)). t=0.416171755 microseconds, dG=  1.68 kcal/mol
# .......(.....).. t=0.417877750 microseconds, dG=  2.83 kcal/mol
# ......((.....)). t=0.418044111 microseconds, dG=  1.68 kcal/mol
# .....(((.....))) t=0.418635116 microseconds, dG=  0.46 kcal/mol
# ......((.....)). t=0.428125930 microseconds, dG=  1.68 kcal/mol
# .......(.....).. t=0.429112980 microseconds, dG=  2.83 kcal/mol
# ................ t=0.429399554 microseconds, dG=  0.00 kcal/mol
# .(...).......... t=0.439331969 microseconds, dG=  3.23 kcal/mol
# ................ t=0.440214767 microseconds, dG=  0.00 kcal/mol
# .....(....)..... t=0.440717832 microseconds, dG=  1.46 kcal/mol
# ................ t=0.441929388 microseconds, dG=  0.00 kcal/mol
# ...(.....)...... t=0.443233097 microseconds, dG=  1.95 kcal/mol
# ................ t=0.448292039 microseconds, dG=  0.00 kcal/mol
# .(.........).... t=0.448869057 microseconds, dG=  3.68 kcal/mol
# .(.(....)..).... t=0.448895669 microseconds, dG=  4.68 kcal/mol
# ((.(....)..))... t=0.449446534 microseconds, dG=  3.69 kcal/mol
# ((.........))... t=0.449831917 microseconds, dG=  2.69 kcal/mol
# .(.........).... t=0.451084581 microseconds, dG=  3.68 kcal/mol
# ((.........))... t=0.451394051 microseconds, dG=  2.69 kcal/mol
# .(.........).... t=0.452138862 microseconds, dG=  3.68 kcal/mol
# .(.(....)..).... t=0.452871750 microseconds, dG=  4.68 kcal/mol
# ...(....)....... t=0.453485931 microseconds, dG=  2.15 kcal/mol
# ................ t=0.457154145 microseconds, dG=  0.00 kcal/mol
# .....(....)..... t=0.460130901 microseconds, dG=  1.46 kcal/mol
# ................ t=0.460979989 microseconds, dG=  0.00 kcal/mol
# ...(.....)...... t=0.461309727 microseconds, dG=  1.95 kcal/mol
# ................ t=0.461947851 microseconds, dG=  0.00 kcal/mol
# ...(.....)...... t=0.464959836 microseconds, dG=  1.95 kcal/mol
# ................ t=0.466235087 microseconds, dG=  0.00 kcal/mol
# .....(....)..... t=0.466573003 microseconds, dG=  1.46 kcal/mol
# ................ t=0.466680952 microseconds, dG=  0.00 kcal/mol
# ...(.....)...... t=0.470197034 microseconds, dG=  1.95 kcal/mol
# ................ t=0.473690499 microseconds, dG=  0.00 kcal/mol
# .....(....)..... t=0.475546678 microseconds, dG=  1.46 kcal/mol
# ................ t=0.475704292 microseconds, dG=  0.00 kcal/mol
# ...........(...) t=0.482337082 microseconds, dG=  2.89 kcal/mol
# ................ t=0.483499881 microseconds, dG=  0.00 kcal/mol
# ........(.....). t=0.484238487 microseconds, dG=  2.58 kcal/mol
# ........((...)). t=0.484453722 microseconds, dG=  2.63 kcal/mol
# ........(.....). t=0.486069635 microseconds, dG=  2.58 kcal/mol
# ........((...)). t=0.486504442 microseconds, dG=  2.63 kcal/mol
# ........(.....). t=0.490279220 microseconds, dG=  2.58 kcal/mol
# ........((...)). t=0.491432429 microseconds, dG=  2.63 kcal/mol
# ........(.....). t=0.491941928 microseconds, dG=  2.58 kcal/mol
# ................ t=0.492146148 microseconds, dG=  0.00 kcal/mol
# ........(....).. t=0.492405862 microseconds, dG=  3.03 kcal/mol
# ................ t=0.492895568 microseconds, dG=  0.00 kcal/mol
# .....(....)..... t=0.493109721 microseconds, dG=  1.46 kcal/mol
# ....((....)).... t=0.493766061 microseconds, dG=  1.70 kcal/mol
# ...(((....)))... t=0.493853319 microseconds, dG=  0.00 kcal/mol
# ...((......))... t=0.496030960 microseconds, dG=  1.38 kcal/mol
# ...(((....)))... t=0.496807904 microseconds, dG=  0.00 kcal/mol
# ....((....)).... t=0.499359600 microseconds, dG=  1.70 kcal/mol
# ...(((....)))... t=0.499477802 microseconds, dG=  0.00 kcal/mol
# ..((((....)))).. t=0.505829061 microseconds, dG=  0.39 kcal/mol
# .(((((....))))). t=0.506083853 microseconds, dG= -0.76 kcal/mol
# ..((((....)))).. t=0.506501087 microseconds, dG=  0.39 kcal/mol
# ...(((....)))... t=0.507894388 microseconds, dG=  0.00 kcal/mol
# ..((((....)))).. t=0.510404571 microseconds, dG=  0.39 kcal/mol
# ..((.(....).)).. t=0.510581678 microseconds, dG=  2.85 kcal/mol
# ..((((....)))).. t=0.510695766 microseconds, dG=  0.39 kcal/mol
# .(((((....))))). t=0.510945786 microseconds, dG= -0.76 kcal/mol
# ((((((....)))))) t=0.511370529 microseconds, dG= -1.27 kcal/mol
# Original run's time: 0.00323815 microseconds
